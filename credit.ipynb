# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow import keras
from keras.layers import Dense, Dropout
from keras.models import Sequential, Model
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import  accuracy_score

# %%
DATA_DIR = 'E:/DL/datasets/creditcard.csv'

# %%
df = pd.read_csv(DATA_DIR)
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
df.drop(['Time', 'Amount'], axis=1, inplace=True)
df
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V20       V21  \
# ...

# %%
train_data = df.drop('Class', axis=1)
train_label = df['Class']

# %%
train_data
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V19       V20  \
# ...

# %%
train_label
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64

# %%
x_train,x_test,y_train,y_test = train_test_split(train_data, train_label, test_size=0.2, random_state=42)

# %%
x_train.shape
# Out:
# (227845, 28)

# %%
x_test.shape
# Out:
# (56962, 28)

# %%
x_test
# Out:
#                V1        V2         V3        V4         V5        V6  \
# 43428  -16.526507  8.584972 -18.649853  9.505594 -13.793819 -2.832404
# 49906    0.339812 -2.743745  -0.134070 -1.385729  -1.451413  1.015887
# 29474    1.399590 -0.590701   0.168619 -1.029950  -0.539806  0.040444
# 276481  -0.432071  1.647895  -1.669361 -0.349504   0.785785 -0.630647
# 278846   2.014160 -0.137394  -1.015839  0.327269  -0.182179 -0.956571
# ...           ...       ...        ...       ...        ...       ...
# 75723   -1.994348  1.503076  -0.365560  0.780223  -0.957956  0.038648
# 252263  -0.234567  0.733694   0.486250 -0.718186   0.782227 -0.788837
# 221246   0.040441 -0.109737  -1.266430  1.004783   2.223390 -0.670372
# 81910   -0.495048  0.991481   1.671584 -0.342474   0.470012 -0.348503
# 59490   -1.590486  0.992415  -0.512841  1.120752  -1.916756  3.142176
#
#                V7        V8        V9        V10  ...       V19       V20  \
# ...

# %%
y_train.shape
# Out:
# (227845,)

# %%
y_train.unique()
# Out:
# array([0, 1])

# %%
train_idx = y_train[y_train==1].index
train_idx
# Out:
# Index([276071,  44556, 251891, 150677, 149869, 152019, 252124, 221041, 239499,
#         43160,
#        ...
#        238366, 125342,  86155, 150644, 153885,  42674,  33276, 182992, 154697,
#        226814],
#       dtype='int64', length=394)

# %%
training_data = x_train.loc[train_idx]
training_data
# Out:
#                V1        V2         V3         V4         V5        V6  \
# 276071   2.091900 -0.757459  -1.192258  -0.755458  -0.620324 -0.322077
# 44556   -4.566342  3.353451  -4.572028   3.616119  -2.493138 -1.090000
# 251891   1.878230  1.325630  -2.333469   4.233151   1.355184 -0.853508
# 150677 -13.086519  7.352148 -18.256576  10.648505 -11.731476 -3.659167
# 149869  -1.108478  3.448953  -6.216972   3.021052  -0.529901 -2.551375
# ...           ...       ...        ...        ...        ...       ...
# 42674   -7.896886  5.381020  -8.451162   7.963928  -7.862419 -2.376820
# 33276   -7.923891 -5.198360  -3.000024   4.420666   2.272194 -3.394483
# 182992   1.889618  1.073099  -1.678018   4.173268   1.015516 -0.009389
# 154697  -4.221221  2.871121  -5.888716   6.890952  -3.404894 -1.154394
# 226814  -2.405207  2.943823  -7.616654   3.533374  -5.417494 -0.112632
#
#                V7        V8        V9        V10  ...       V19       V20  \
# ...

# %%
min_max_scaler = MinMaxScaler(feature_range=(0,1))
x_train_scaled = min_max_scaler.fit_transform(training_data.copy())
x_test_scaled = min_max_scaler.transform(x_test.copy())

# %%
x_train_scaled.shape
# Out:
# (394, 28)

# %%
class AutoEncoder(Model):
    def __init__(self, output_units, ldim=8):
        super().__init__()
        self.encoder = Sequential([
            Dense(64, activation='relu'),
            Dropout(0.1),
            Dense(32, activation='relu'),
            Dropout(0.1),
            Dense(16, activation='relu'),
            Dropout(0.1),
            Dense(ldim, activation='relu')
        ])

        self.decoder = Sequential([
            Dense(16, activation='relu'),
            Dropout(0.1),
            Dense(32, activation='relu'),
            Dropout(0.1),
            Dense(64, activation='relu'),
            Dropout(0.1),
            Dense(output_units, activation='sigmoid')
        ])

    def call(self, inputs):
        encoded = self.encoder(inputs)
        decoded = self.decoder(encoded)
        return decoded

# %%
model = AutoEncoder(output_units=x_train_scaled.shape[1])

model.compile(optimizer='adam', loss='msle' ,metrics=['mse'])
history = model.fit(x_train_scaled,x_train_scaled,batch_size=512,epochs=20,validation_data=(x_test_scaled,x_test_scaled))
# Out:
# Epoch 1/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 0.0208 - mse: 0.0491 - val_loss: 0.0309 - val_mse: 0.0759
# Epoch 2/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - loss: 0.0206 - mse: 0.0488 - val_loss: 0.0306 - val_mse: 0.0752
# Epoch 3/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - loss: 0.0204 - mse: 0.0484 - val_loss: 0.0303 - val_mse: 0.0744
# Epoch 4/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - loss: 0.0203 - mse: 0.0479 - val_loss: 0.0299 - val_mse: 0.0735
# Epoch 5/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - loss: 0.0201 - mse: 0.0474 - val_loss: 0.0295 - val_mse: 0.0725
# Epoch 6/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - loss: 0.0198 - mse: 0.0469 - val_loss: 0.0290 - val_mse: 0.0714
# Epoch 7/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - loss: 0.0196 - mse: 0.0463 - val_loss: 0.0285 - val_mse: 0.0702
# Epoch 8/20
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - loss: 0.0193 - mse: 0.0457 - val_loss: 0.0280 - val_mse: 0.0689
# Epoch 9/20
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.legend()

# %%
plt.plot(history.history["mse"], label="Training Loss")
plt.plot(history.history["val_mse"], label="Validation Loss")
plt.legend()

# %%
def find_thresholf(model,x_trained_scale):
  reconstructions = model.predict(x_trained_scale)
  reconstructions_error = keras.metrics.msle(reconstructions,x_trained_scale)
  threshold = np.mean(reconstructions_error.numpy()) + np.std(reconstructions_error.numpy())
  return threshold

def get_predictions(model,x_test_scaled,threshold):
  predictions = model.predict(x_test_scaled)
  error = keras.losses.msle(predictions,x_test_scaled)
  anomaly_mask = pd.Series(error) > threshold
  preds = anomaly_mask.map(lambda x: 0.0 if x == True else 1.0)
  return preds

# %%
threshold = find_thresholf(model,x_train_scaled)
threshold
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# np.float64(0.022646469136419684)

# %%
predictions = get_predictions(model,x_test_scaled,threshold)
predictions
# Out:
# 1781/1781 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 0        0.0
# 1        1.0
# 2        1.0
# 3        1.0
# 4        1.0
#         ...
# 56957    1.0
# 56958    1.0
# 56959    1.0
# 56960    1.0
# 56961    1.0
# Length: 56962, dtype: float64

# %%
accuracy = accuracy_score(y_test,predictions)
accuracy
# Out:
# 0.03688423861521716
